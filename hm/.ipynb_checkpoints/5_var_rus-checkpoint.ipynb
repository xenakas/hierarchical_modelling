# %%
gdp_agg <- read.csv(file='data/rus_gdp_q9518.csv', header=TRUE, sep=",")

# %%
gdp_ind <- read.csv(file='data/rus_gdp_qind.csv', header=TRUE, sep=",")

# %%
gdp_spen <- read.csv(file='data/rus_gdp_qspen.csv', header=TRUE, sep=",")

# %%
gdp_spen
# Out:
#    X          Валовой.внутренний.продукт Расходы.домашних.хозяйств
# 1  1995-01-01  235.0                      126.0
# 2  1995-04-01  324.3                      163.7
# 3  1995-07-01  421.1                      200.9
# 4  1995-10-01  448.2                      229.2
# 5  1996-01-01  425.3                      230.0
# 6  1996-04-01  468.4                      242.9
# 7  1996-07-01  548.9                      256.1
# 8  1996-10-01  565.2                      278.8
# 9  1997-01-01  512.4                      282.8
# 10 1997-04-01  555.1                      292.0
# 11 1997-07-01  634.2                      315.0
# 12 1997-10-01  640.9                      345.4
# 13 1998-01-01  550.9                      307.2
# 14 1998-04-01  602.5                      312.4
# 15 1998-07-01  675.5                      371.6
# 16 1998-10-01  800.8                      471.1
# 17 1999-01-01  901.3                      536.7
# 18 1999-04-01 1101.5                      580.5
# ...
