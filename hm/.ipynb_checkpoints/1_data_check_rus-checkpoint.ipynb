# %% [markdown]
# ### 1. Данные для РФ

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ВВП годовой

# %%
rus_gdp = pd.read_csv('data/rus_gdp_y9518.csv', index_col=0, header=[0], parse_dates=True)
rus_gdp.plot();

# %% [markdown]
# ВРП для 79 регионов и 3 городов

# %%
rus_vrp = pd.read_csv('data/rus_vrp.csv', index_col=0, header=[0], parse_dates=True)
rus_vrp.plot(legend=False);

# %% [markdown]
# ВВП для 79 регионов и каждой из 12 отраслей

# %%
rus_vrp_ind = pd.read_csv('data/rus_vrp_ind.csv', index_col=0, header=[0], parse_dates=True)
rus_vrp_ind.plot(legend=False);

# %% [markdown]
# Разница между ВВП  и суммой ВРП по регионам?????

# %%
rus_gdp.mul(1000).plot();

# %%
rus_gdp.iloc[3:-2,].mul(1000).sub(rus_vrp.sum(axis=1), axis=0).plot();

# %% [markdown]
# ВВП квартальный (производственный)

# %%
import matplotlib.pyplot as plt

# %%
rus_gdp_qind = pd.read_csv('data/rus_gdp_qind.csv', index_col=0, header=[0], parse_dates=True).iloc[:,2:]

# %%
rus_gdp_qind.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'O',
#        'Налоги на продукты ', 'Субсидии на продукты'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(10,7))
plt.plot(rus_gdp_qind)
plt.legend(rus_gdp_qind.columns)
plt.show()

# %%
tax = rus_gdp_qind.iloc[:-7,-2:].resample('Y').sum().sum(axis=1)

# %%
rus_gdp.iloc[8:-2,].mul(1000).sub(rus_vrp.sum(axis=1)[5:], axis=0).sub(tax.values*1000,  axis=0).div(rus_gdp.iloc[8:-2,].mul(1000)).plot();

# %%
rus_gdp.iloc[3:-2,].mul(1000).sub(rus_vrp.sum(axis=1), axis=0).div(rus_gdp.iloc[3:-2,].mul(1000)).plot();

# %% [markdown]
# Разница между ВВП и суммой ВРП по регионам по отраслям, без 3 городов

# %%
rus_gdp.iloc[9:-2,].mul(1000).sub(rus_vrp_ind.sum(axis=1), axis=0).plot();

# %% [markdown]
# ВВП квартальный

# %%
rus_gdp_q = pd.read_csv('data/rus_gdp_q9518.csv', index_col=0, header=[0], parse_dates=True)
rus_gdp_q.plot();

# %% [markdown]
# Разница между ВВП и суммой ВВП по расходам

# %%
rus_gdp_q.iloc[32:,].sub(rus_gdp_qind.sum(axis=1), axis=0).plot();

# %%
rus_gdp_q.iloc[32:,].sub(rus_gdp_qind.sum(axis=1), axis=0).div(rus_gdp_q.iloc[32:,]).plot();

# %% [markdown]
# ВВП квартальный (по расходам)

# %%
rus_gdp_qspen = pd.read_csv('data/rus_gdp_qspen.csv', index_col=0, header=[0],  parse_dates=True).iloc[:,1:]

# %%
fig = plt.figure(figsize=(10,7))
plt.plot(rus_gdp_qspen)
plt.legend(rus_gdp_qspen.columns)
plt.show()

# %%
rus_gdp_q.sub(rus_gdp_qspen.sum(axis=1), axis=0).plot();
