# %%
library(eurostat)
library(lubridate)
# Out:
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %%
dat <- get_eurostat(id="namq_10_a10", time_format="date")
# Out:
# Table namq_10_a10 cached at /tmp/Rtmp2hTMvU/eurostat/namq_10_a10_date_code_TF.rds

# %%
head(dat)
# Out:
#   unit       s_adj nace_r2 na_item geo time       values
# 1 CLV05_MEUR CA    A       B1G     FR  2018-10-01  7959.7
# 2 CLV05_MEUR CA    A       B1G     LT  2018-10-01   114.7
# 3 CLV05_MEUR CA    B-E     B1G     FR  2018-10-01 69097.4
# 4 CLV05_MEUR CA    B-E     B1G     LT  2018-10-01  1792.8
# 5 CLV05_MEUR CA    C       B1G     FR  2018-10-01 59016.0
# 6 CLV05_MEUR CA    C       B1G     LT  2018-10-01  1605.2

# %%
label_eurostat_tables("namq_10_a10", lang = "en")
# Out:
# [1] "Gross value added and income A*10 industry breakdowns"

# %%
colname = label_eurostat_vars(dat, lang = "en")
colname
# Out:
# [1] "Unit of measure"
# [2] "Seasonal adjustment"
# [3] "Classification of economic activities - NACE Rev.2"
# [4] "National accounts indicator (ESA 2010)"
# [5] "Geopolitical entity (reporting)"
# [6] "Period of time (a=annual, q=quarterly, m=monthly, d=daily, c=cumulated from January)"

# %%
name = label_eurostat(dat)
name
# Out:
#         unit
# 1       Chain linked volumes (2005), million euro
# 2       Chain linked volumes (2005), million euro
# 3       Chain linked volumes (2005), million euro
# 4       Chain linked volumes (2005), million euro
# 5       Chain linked volumes (2005), million euro
# 6       Chain linked volumes (2005), million euro
# 7       Chain linked volumes (2005), million euro
# 8       Chain linked volumes (2005), million euro
# 9       Chain linked volumes (2005), million euro
# 10      Chain linked volumes (2005), million euro
# 11      Chain linked volumes (2005), million euro
# 12      Chain linked volumes (2005), million euro
# 13      Chain linked volumes (2005), million euro
# 14      Chain linked volumes (2005), million euro
# 15      Chain linked volumes (2005), million euro
# 16      Chain linked volumes (2005), million euro
# 17      Chain linked volumes (2005), million euro
# 18      Chain linked volumes (2005), million euro
# 19      Chain linked volumes (2005), million euro
# 20      Chain linked volumes (2005), million euro
# 21      Chain linked volumes (2005), million euro
# 22      Chain linked volumes (2005), million euro
# 23      Chain linked volumes (2005), million euro
# 24      Chain linked volumes (2005), million euro
# 25      Chain linked volumes (2005), million euro
# 26      Chain linked volumes (2005), million euro
# 27      Chain linked volumes (2005), million euro
# 28      Chain linked volumes (2005), million euro
# 29      Chain linked volumes (2005), million euro
# 30      Chain linked volumes (2005), million euro
# ⋮       ⋮
# 2995241 Chain linked volumes (2010), million euro
# 2995242 Chain linked volumes (2010), million units of national currency
# 2995243 Chain linked volumes, index 2005=100
# 2995244 Chain linked volumes, index 2010=100
# 2995245 Chain linked volumes, percentage change on previous period
# 2995246 Chain linked volumes, percentage change compared to same period in previous year
# 2995247 Chain linked volumes (2005), million euro
# 2995248 Chain linked volumes (2005), million units of national currency
# 2995249 Chain linked volumes (2010), million euro
# 2995250 Chain linked volumes (2010), million units of national currency
# 2995251 Chain linked volumes, index 2005=100
# 2995252 Chain linked volumes, index 2010=100
# 2995253 Chain linked volumes, percentage change on previous period
# 2995254 Chain linked volumes, percentage change compared to same period in previous year
# 2995255 Chain linked volumes (2005), million euro
# 2995256 Chain linked volumes (2005), million units of national currency
# 2995257 Chain linked volumes (2010), million euro
# 2995258 Chain linked volumes (2010), million units of national currency
# 2995259 Chain linked volumes, index 2005=100
# 2995260 Chain linked volumes, index 2010=100
# 2995261 Chain linked volumes, percentage change on previous period
# 2995262 Chain linked volumes, percentage change compared to same period in previous year
# 2995263 Chain linked volumes (2005), million euro
# 2995264 Chain linked volumes (2005), million units of national currency
# 2995265 Chain linked volumes (2010), million euro
# 2995266 Chain linked volumes (2010), million units of national currency
# 2995267 Chain linked volumes, index 2005=100
# 2995268 Chain linked volumes, index 2010=100
# 2995269 Chain linked volumes, percentage change on previous period
# 2995270 Chain linked volumes, percentage change compared to same period in previous year
#         s_adj
# 1       Calendar adjusted data, not seasonally adjusted data
# 2       Calendar adjusted data, not seasonally adjusted data
# 3       Calendar adjusted data, not seasonally adjusted data
# 4       Calendar adjusted data, not seasonally adjusted data
# 5       Calendar adjusted data, not seasonally adjusted data
# 6       Calendar adjusted data, not seasonally adjusted data
# 7       Calendar adjusted data, not seasonally adjusted data
# 8       Calendar adjusted data, not seasonally adjusted data
# 9       Calendar adjusted data, not seasonally adjusted data
# 10      Calendar adjusted data, not seasonally adjusted data
# 11      Calendar adjusted data, not seasonally adjusted data
# 12      Calendar adjusted data, not seasonally adjusted data
# 13      Calendar adjusted data, not seasonally adjusted data
# 14      Calendar adjusted data, not seasonally adjusted data
# 15      Calendar adjusted data, not seasonally adjusted data
# 16      Calendar adjusted data, not seasonally adjusted data
# 17      Calendar adjusted data, not seasonally adjusted data
# 18      Calendar adjusted data, not seasonally adjusted data
# 19      Calendar adjusted data, not seasonally adjusted data
# 20      Calendar adjusted data, not seasonally adjusted data
# 21      Calendar adjusted data, not seasonally adjusted data
# 22      Calendar adjusted data, not seasonally adjusted data
# 23      Calendar adjusted data, not seasonally adjusted data
# 24      Calendar adjusted data, not seasonally adjusted data
# 25      Calendar adjusted data, not seasonally adjusted data
# 26      Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# 27      Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# 28      Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# 29      Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# 30      Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# ⋮       ⋮
# 2995241 Seasonally and calendar adjusted data
# 2995242 Seasonally and calendar adjusted data
# 2995243 Seasonally and calendar adjusted data
# 2995244 Seasonally and calendar adjusted data
# 2995245 Seasonally and calendar adjusted data
# 2995246 Seasonally and calendar adjusted data
# 2995247 Seasonally and calendar adjusted data
# 2995248 Seasonally and calendar adjusted data
# 2995249 Seasonally and calendar adjusted data
# 2995250 Seasonally and calendar adjusted data
# 2995251 Seasonally and calendar adjusted data
# 2995252 Seasonally and calendar adjusted data
# 2995253 Seasonally and calendar adjusted data
# 2995254 Seasonally and calendar adjusted data
# 2995255 Seasonally and calendar adjusted data
# 2995256 Seasonally and calendar adjusted data
# 2995257 Seasonally and calendar adjusted data
# 2995258 Seasonally and calendar adjusted data
# 2995259 Seasonally and calendar adjusted data
# 2995260 Seasonally and calendar adjusted data
# 2995261 Seasonally and calendar adjusted data
# 2995262 Seasonally and calendar adjusted data
# 2995263 Seasonally and calendar adjusted data
# 2995264 Seasonally and calendar adjusted data
# 2995265 Seasonally and calendar adjusted data
# 2995266 Seasonally and calendar adjusted data
# 2995267 Seasonally and calendar adjusted data
# 2995268 Seasonally and calendar adjusted data
# 2995269 Seasonally and calendar adjusted data
# 2995270 Seasonally and calendar adjusted data
#         nace_r2
# 1       Agriculture, forestry and fishing
# 2       Agriculture, forestry and fishing
# 3       Industry (except construction)
# 4       Industry (except construction)
# 5       Manufacturing
# 6       Manufacturing
# 7       Construction
# 8       Construction
# 9       Wholesale and retail trade, transport, accomodation and food service activities
# 10      Wholesale and retail trade, transport, accomodation and food service activities
# 11      Information and communication
# 12      Information and communication
# 13      Financial and insurance activities
# 14      Financial and insurance activities
# 15      Real estate activities
# 16      Real estate activities
# 17      Professional, scientific and technical activities; administrative and support service activities
# 18      Professional, scientific and technical activities; administrative and support service activities
# 19      Public administration, defence, education, human health and social work activities
# 20      Public administration, defence, education, human health and social work activities
# 21      Arts, entertainment and recreation; other service activities; activities of household and extra-territorial organizations and bodies
# 22      Arts, entertainment and recreation; other service activities; activities of household and extra-territorial organizations and bodies
# 23      Total - all NACE activities
# 24      Total - all NACE activities
# 25      Total - all NACE activities
# 26      Agriculture, forestry and fishing
# 27      Agriculture, forestry and fishing
# 28      Agriculture, forestry and fishing
# 29      Agriculture, forestry and fishing
# 30      Agriculture, forestry and fishing
# ⋮       ⋮
# 2995241 Total - all NACE activities
# 2995242 Total - all NACE activities
# 2995243 Total - all NACE activities
# 2995244 Total - all NACE activities
# 2995245 Total - all NACE activities
# 2995246 Total - all NACE activities
# 2995247 Total - all NACE activities
# 2995248 Total - all NACE activities
# 2995249 Total - all NACE activities
# 2995250 Total - all NACE activities
# 2995251 Total - all NACE activities
# 2995252 Total - all NACE activities
# 2995253 Total - all NACE activities
# 2995254 Total - all NACE activities
# 2995255 Total - all NACE activities
# 2995256 Total - all NACE activities
# 2995257 Total - all NACE activities
# 2995258 Total - all NACE activities
# 2995259 Total - all NACE activities
# 2995260 Total - all NACE activities
# 2995261 Total - all NACE activities
# 2995262 Total - all NACE activities
# 2995263 Total - all NACE activities
# 2995264 Total - all NACE activities
# 2995265 Total - all NACE activities
# 2995266 Total - all NACE activities
# 2995267 Total - all NACE activities
# 2995268 Total - all NACE activities
# 2995269 Total - all NACE activities
# 2995270 Total - all NACE activities
#         na_item            geo            time       values
# 1       Value added, gross France         2018-10-01   7959.7
# 2       Value added, gross Lithuania      2018-10-01    114.7
# 3       Value added, gross France         2018-10-01  69097.4
# 4       Value added, gross Lithuania      2018-10-01   1792.8
# 5       Value added, gross France         2018-10-01  59016.0
# 6       Value added, gross Lithuania      2018-10-01   1605.2
# 7       Value added, gross France         2018-10-01  19758.3
# 8       Value added, gross Lithuania      2018-10-01    602.9
# 9       Value added, gross France         2018-10-01  84553.6
# 10      Value added, gross Lithuania      2018-10-01   2283.4
# 11      Value added, gross France         2018-10-01  36548.4
# 12      Value added, gross Lithuania      2018-10-01    372.6
# 13      Value added, gross France         2018-10-01  18617.3
# 14      Value added, gross Lithuania      2018-10-01    150.5
# 15      Value added, gross France         2018-10-01  56348.1
# 16      Value added, gross Lithuania      2018-10-01    392.1
# 17      Value added, gross France         2018-10-01  63198.8
# 18      Value added, gross Lithuania      2018-10-01    470.9
# 19      Value added, gross France         2018-10-01  99376.7
# 20      Value added, gross Lithuania      2018-10-01    722.9
# 21      Value added, gross France         2018-10-01  13439.5
# 22      Value added, gross Lithuania      2018-10-01     98.9
# 23      Value added, gross France         2018-10-01 466263.1
# 24      Value added, gross Lithuania      2018-10-01   6968.8
# 25      Value added, gross Netherlands    2018-10-01 152792.6
# 26      Value added, gross Austria        2018-10-01    746.3
# 27      Value added, gross Spain          2018-10-01   9366.4
# 28      Value added, gross France         2018-10-01   7959.1
# 29      Value added, gross Lithuania      2018-10-01    115.4
# 30      Value added, gross Netherlands    2018-10-01   3029.4
# ⋮       ⋮                  ⋮              ⋮          ⋮
# 2995241 Value added, gross United Kingdom 1975-10-01 189035.0
# 2995242 Value added, gross United Kingdom 1975-10-01 162161.8
# 2995243 Value added, gross United Kingdom 1975-10-01     46.4
# 2995244 Value added, gross United Kingdom 1975-10-01     45.4
# 2995245 Value added, gross United Kingdom 1975-10-01      1.3
# 2995246 Value added, gross United Kingdom 1975-10-01     -0.8
# 2995247 Value added, gross United Kingdom 1975-07-01 209452.6
# 2995248 Value added, gross United Kingdom 1975-07-01 143223.7
# 2995249 Value added, gross United Kingdom 1975-07-01 186677.1
# 2995250 Value added, gross United Kingdom 1975-07-01 160139.1
# 2995251 Value added, gross United Kingdom 1975-07-01     45.8
# 2995252 Value added, gross United Kingdom 1975-07-01     44.8
# 2995253 Value added, gross United Kingdom 1975-07-01     -0.5
# 2995254 Value added, gross United Kingdom 1975-07-01     -3.6
# 2995255 Value added, gross United Kingdom 1975-04-01 210600.5
# 2995256 Value added, gross United Kingdom 1975-04-01 144008.6
# 2995257 Value added, gross United Kingdom 1975-04-01 187700.2
# 2995258 Value added, gross United Kingdom 1975-04-01 161016.7
# 2995259 Value added, gross United Kingdom 1975-04-01     46.0
# 2995260 Value added, gross United Kingdom 1975-04-01     45.1
# 2995261 Value added, gross United Kingdom 1975-04-01     -1.5
# 2995262 Value added, gross United Kingdom 1975-04-01     -2.1
# 2995263 Value added, gross United Kingdom 1975-01-01 213867.9
# 2995264 Value added, gross United Kingdom 1975-01-01 146242.9
# 2995265 Value added, gross United Kingdom 1975-01-01 190612.3
# 2995266 Value added, gross United Kingdom 1975-01-01 163514.9
# 2995267 Value added, gross United Kingdom 1975-01-01     46.8
# 2995268 Value added, gross United Kingdom 1975-01-01     45.8
# 2995269 Value added, gross United Kingdom 1975-01-01      0.0
# 2995270 Value added, gross United Kingdom 1975-01-01      0.8

# %%
na_item <- unique(name$na_item)
na_item
# Out:
# [1] Value added, gross              Compensation of employees
# [3] Wages and salaries              Employers' social contributions
# 4 Levels: Value added, gross Compensation of employees ... Employers' social contributions

# %%
na_item <- unique(dat$na_item)
na_item
# Out:
# [1] B1G D1  D11 D12
# Levels: B1G D1 D11 D12

# %%
s_adj <- unique(name$s_adj, incomparables = FALSE)
s_adj
# Out:
# [1] Calendar adjusted data, not seasonally adjusted data
# [2] Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
# [3] Seasonally and calendar adjusted data
# [4] Seasonally adjusted data, not calendar adjusted data
# 4 Levels: Calendar adjusted data, not seasonally adjusted data ...

# %%
s_adj <- unique(dat$s_adj, incomparables = FALSE)
s_adj
# Out:
# [1] CA  NSA SCA SA
# Levels: CA NSA SCA SA

# %%
unit <- unique(name$unit, incomparables = FALSE)
unit
# Out:
#  [1] Chain linked volumes (2005), million euro
#  [2] Chain linked volumes (2005), million units of national currency
#  [3] Chain linked volumes (2010), million euro
#  [4] Chain linked volumes (2010), million units of national currency
#  [5] Chain linked volumes, index 2005=100
#  [6] Chain linked volumes, index 2010=100
#  [7] Chain linked volumes, percentage change on previous period
#  [8] Chain linked volumes, percentage change compared to same period in previous year
#  [9] Current prices, million euro
# [10] Current prices, million units of national currency
# [11] Percentage of gross domestic product (GDP)
# [12] Percentage of total
# [13] Price index (implicit deflator), 2005=100, euro
# [14] Price index (implicit deflator), 2005=100, national currency
# [15] Price index (implicit deflator), 2010=100, euro
# [16] Price index (implicit deflator), 2010=100, national currency
# [17] Price index (implicit deflator), percentage change on previous period, euro
# [18] Price index (implicit deflator), percentage change on previous period, national currency
# [19] Price index (implicit deflator), percentage change compared to same period in previous year, euro
# [20] Price index (implicit deflator), percentage change compared to same period in previous year, national currency
# [21] Previous year prices, million euro
# [22] Previous year prices, million units of national currency
# [23] Contribution to GDP growth, percentage point change on previous period
# [24] Contribution to GDP growth, percentage point change compared to same period in previous year
# 24 Levels: Chain linked volumes (2005), million euro ...

# %%
unit <- unique(dat$unit, incomparables = FALSE)
unit
# Out:
#  [1] CLV05_MEUR     CLV05_MNAC     CLV10_MEUR     CLV10_MNAC     CLV_I05
#  [6] CLV_I10        CLV_PCH_PRE    CLV_PCH_SM     CP_MEUR        CP_MNAC
# [11] PC_GDP         PC_TOT         PD05_EUR       PD05_NAC       PD10_EUR
# [16] PD10_NAC       PD_PCH_PRE_EUR PD_PCH_PRE_NAC PD_PCH_SM_EUR  PD_PCH_SM_NAC
# [21] PYP_MEUR       PYP_MNAC       CON_PPCH_PRE   CON_PPCH_SM
# 24 Levels: CLV05_MEUR CLV05_MNAC CLV10_MEUR CLV10_MNAC CLV_I05 ... CON_PPCH_SM

# %%
unit <- unique(name$geo, incomparables = FALSE)
unit
# Out:
#  [1] France
#  [2] Lithuania
#  [3] Netherlands
#  [4] Austria
#  [5] Spain
#  [6] Norway
#  [7] United Kingdom
#  [8] Belgium
#  [9] Switzerland
# [10] Cyprus
# [11] Czechia
# [12] Finland
# [13] Italy
# [14] Luxembourg
# [15] Latvia
# [16] Hungary
# [17] Bulgaria
# [18] Germany (until 1990 former territory of the FRG)
# [19] Denmark
# [20] Euro area (EA11-2000, EA12-2006, EA13-2007, EA15-2008, EA16-2010, EA17-2013, EA18-2014, EA19)
# [21] Euro area (12 countries)
# [22] Euro area (19 countries)
# [23] Estonia
# [24] Greece
# [25] European Union - 15 countries (1995-2004)
# [26] European Union - 27 countries (from 2019)
# [27] European Union - 28 countries
# [28] Croatia
# [29] Ireland
# [30] Former Yugoslav Republic of Macedonia, the
# [31] Poland
# [32] Portugal
# [33] Romania
# [34] Serbia
# [35] Sweden
# [36] Slovenia
# [37] Slovakia
# [38] Turkey
# [39] Malta
# [40] Kosovo (under United Nations Security Council Resolution 1244/99)
# [41] Albania
# [42] Bosnia and Herzegovina
# [43] Montenegro
# 43 Levels: France Lithuania Netherlands Austria Spain Norway ... Montenegro

# %%
#dat_ca <- subset(dat, dat$s_adj==s_adj[1])  # Calendar adjusted data, not seasonally adjusted data
dat_ua <- subset(dat, dat$s_adj==s_adj[2])  # Unadjusted data (i.e. neither seasonally adjusted nor calendar adjusted data)
#dat_sa <- subset(dat, dat$s_adj==s_adj[3]) # Seasonally adjusted data, not calendar adjusted data                         
#dat_sca <- subset(dat, dat$s_adj==s_adj[4]) # Seasonally and calendar adjusted data  
head(dat_ua)
# Out:
#   unit       s_adj nace_r2 na_item geo time       values
# 1 CLV05_MEUR CA    A       B1G     FR  2018-10-01  7959.7
# 2 CLV05_MEUR CA    A       B1G     LT  2018-10-01   114.7
# 3 CLV05_MEUR CA    B-E     B1G     FR  2018-10-01 69097.4
# 4 CLV05_MEUR CA    B-E     B1G     LT  2018-10-01  1792.8
# 5 CLV05_MEUR CA    C       B1G     FR  2018-10-01 59016.0
# 6 CLV05_MEUR CA    C       B1G     LT  2018-10-01  1605.2

# %%
dat_1 <- subset(dat_ua, dat_ua$unit==unit[1])  # [1] Chain linked volumes (2005), million euro                                                                     
#dat_2 <- subset(dat_ua, dat_ua$unit==unit[2]) # [2] Chain linked volumes (2005), million units of national currency                                               
#dat_3 <- subset(dat_ua, dat_ua$unit==unit[3]) # [3] Chain linked volumes (2010), million euro                                                                     
#dat_4 <- subset(dat_ua, dat_ua$unit==unit[4]) # [4] Chain linked volumes (2010), million units of national currency 
head(dat_1)
# Out:
#   unit       s_adj nace_r2 na_item geo time       values
# 1 CLV05_MEUR CA    A       B1G     FR  2018-10-01  7959.7
# 2 CLV05_MEUR CA    A       B1G     LT  2018-10-01   114.7
# 3 CLV05_MEUR CA    B-E     B1G     FR  2018-10-01 69097.4
# 4 CLV05_MEUR CA    B-E     B1G     LT  2018-10-01  1792.8
# 5 CLV05_MEUR CA    C       B1G     FR  2018-10-01 59016.0
# 6 CLV05_MEUR CA    C       B1G     LT  2018-10-01  1605.2

# %%
geo <- unique(name$geo, incomparables = FALSE) 
geo
# Out:
#  [1] France
#  [2] Lithuania
#  [3] Netherlands
#  [4] Austria
#  [5] Spain
#  [6] Norway
#  [7] United Kingdom
#  [8] Belgium
#  [9] Switzerland
# [10] Cyprus
# [11] Czechia
# [12] Finland
# [13] Italy
# [14] Luxembourg
# [15] Latvia
# [16] Hungary
# [17] Bulgaria
# [18] Germany (until 1990 former territory of the FRG)
# [19] Denmark
# [20] Euro area (EA11-2000, EA12-2006, EA13-2007, EA15-2008, EA16-2010, EA17-2013, EA18-2014, EA19)
# [21] Euro area (12 countries)
# [22] Euro area (19 countries)
# [23] Estonia
# [24] Greece
# [25] European Union - 15 countries (1995-2004)
# [26] European Union - 27 countries (from 2019)
# [27] European Union - 28 countries
# [28] Croatia
# [29] Ireland
# [30] Former Yugoslav Republic of Macedonia, the
# [31] Poland
# [32] Portugal
# [33] Romania
# [34] Serbia
# [35] Sweden
# [36] Slovenia
# [37] Slovakia
# [38] Turkey
# [39] Malta
# [40] Kosovo (under United Nations Security Council Resolution 1244/99)
# [41] Albania
# [42] Bosnia and Herzegovina
# [43] Montenegro
# 43 Levels: France Lithuania Netherlands Austria Spain Norway ... Montenegro

# %%
geo <- unique(dat$geo, incomparables = FALSE) 
geo
# Out:
#  [1] FR        LT        NL        AT        ES        NO        UK
#  [8] BE        CH        CY        CZ        FI        IT        LU
# [15] LV        HU        BG        DE        DK        EA        EA12
# [22] EA19      EE        EL        EU15      EU27_2019 EU28      HR
# [29] IE        MK        PL        PT        RO        RS        SE
# [36] SI        SK        TR        MT        XK        AL        BA
# [43] ME
# 43 Levels: FR LT NL AT ES NO UK BE CH CY CZ FI IT LU LV HU BG DE DK EA ... ME

# %%
nace <- unique(name$nace_r2, incomparables = FALSE)
nace
# Out:
#  [1] Agriculture, forestry and fishing
#  [2] Industry (except construction)
#  [3] Manufacturing
#  [4] Construction
#  [5] Wholesale and retail trade, transport, accomodation and food service activities
#  [6] Information and communication
#  [7] Financial and insurance activities
#  [8] Real estate activities
#  [9] Professional, scientific and technical activities; administrative and support service activities
# [10] Public administration, defence, education, human health and social work activities
# [11] Arts, entertainment and recreation; other service activities; activities of household and extra-territorial organizations and bodies
# [12] Total - all NACE activities
# 12 Levels: Agriculture, forestry and fishing ... Total - all NACE activities

# %%
nace <- unique(dat$nace_r2, incomparables = FALSE)
nace
# Out:
#  [1] A     B-E   C     F     G-I   J     K     L     M_N   O-Q   R-U   TOTAL
# Levels: A B-E C F G-I J K L M_N O-Q R-U TOTAL

# %%
#### Chain linked volumes (2005), million euro + Unadjusted data ####
dat_1$unit <- NULL
dat_1$s_adj <- NULL
dat_1$na_item <- NULL
head(dat_1)
# Out:
#   nace_r2 geo time       values
# 1 A       FR  2018-10-01  7959.7
# 2 A       LT  2018-10-01   114.7
# 3 B-E     FR  2018-10-01 69097.4
# 4 B-E     LT  2018-10-01  1792.8
# 5 C       FR  2018-10-01 59016.0
# 6 C       LT  2018-10-01  1605.2

# %%
write.csv(dat_1, file = "gdp_eu.csv")

# %%
# nace_list <- list()
# for (i  in 1:length(nace) ) {
#   nace_list[[nace[i]]] <-  subset(dat_1, dat_1$nace_r2 == nace[i])
#   nace_list[[nace[i]]]$nace_r2 <- NULL
#       }

geo_list <- list()
for (i  in 1:length(geo) ) {
  geo_list[[geo[i]]] <-  subset(dat_1, dat_1$geo == geo[i])
  geo_list[[geo[i]]]$geo <- NULL
}

# %%
library(zoo)
library(xts)

# %%
main_list <- list()
for (i  in 1:length(geo) ) {
  main_list[[i]] <- list()
  for (j in 1:length(nace)){
  main_list[[i]][[j]] <- subset(geo_list[[i]], geo_list[[i]]$nace_r2 == nace[j])
  main_list[[i]][[j]]$nace_r2 <- NULL
  }
}

# %%
main_list[[11]][[2]]

# %%
library(forecast)
ggtsdisplay(main_list[[3]][[2]][2])
library(ggplot2)

# %%
date <- rev(seq(as.Date("1980-01-01"), as.Date("2018-04-01"), by="quarters") )

# %%
for(i in 1:length(geo)){
  the_main_list[[i]] <- matrix(ncol = length(nace)+1, nrow = length(main_list[[i]][[1]]$values))
  for (j in 1:length(nace)){
    the_main_list[[i]][,j+1] <- main_list[[i]][[j]]$values
  }
  the_main_list[[i]] <- data.frame(the_main_list[[i]])
  colnames(the_main_list[[i]]) <- c("time", as.character(nace))
  the_main_list[[i]]$time <- main_list[[i]][[1]]$time    
  }

# %%
ts.plot(the_main_list[[15]])

# %%
main_list[[i]][[j]]<-xts(main_list[[i]][[j]]$values, as.Date(main_list[[i]][[j]]$time, format='%Y-%m-%d'))

#http://ec.europa.eu/eurostat/ramon/nomenclatures/index.cfm?TargetUrl=LST_NOM_DTL&StrNom=CL_NACE2&StrLanguageCode=EN&IntPcKey=&StrLayoutCode=HIERARCHIC
