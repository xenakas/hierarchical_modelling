# %%
import pandas as pd
import numpy as np

# %%
clear_labelled = pd.read_csv('clear_labelled.csv', header=[0,1])
clear_labelled.describe()
# Out:
#                                 Albania  \
#       Agriculture, forestry and fishing
# count                         42.000000
# mean                         467.995238
# std                          126.139389
# min                          287.100000
# 25%                          371.200000
# 50%                          445.950000
# 75%                          537.350000
# max                          801.400000
#
#                                                                                                                                             \
#       Arts, entertainment and recreation; other service activities; activities of household and extra-territorial organizations and bodies
# count                                          42.000000
# mean                                           56.902381
# std                                            15.356344
# min                                            30.300000
# ...

# %%
count_labelled = pd.read_csv('count_labelled.csv', header=[0,1])
count_labelled
# Out:
#     Unnamed: 0_level_0 nace_r2                                           \
#                    geo Albania  Austria  Belgium Bosnia and Herzegovina
# 0                 time     NaN      NaN      NaN                    NaN
# 1           1975-01-01     NaN      NaN      NaN                    NaN
# 2           1975-04-01     NaN      NaN      NaN                    NaN
# 3           1975-07-01     NaN      NaN      NaN                    NaN
# 4           1975-10-01     NaN      NaN      NaN                    NaN
# 5           1976-01-01     NaN      NaN      NaN                    NaN
# 6           1976-04-01     NaN      NaN      NaN                    NaN
# 7           1976-07-01     NaN      NaN      NaN                    NaN
# 8           1976-10-01     NaN      NaN      NaN                    NaN
# 9           1977-01-01     NaN      NaN      NaN                    NaN
# 10          1977-04-01     NaN      NaN      NaN                    NaN
# ...

# %%
count_labelled.describe()
# Out:
#            nace_r2                                                     \
#            Albania       Austria       Belgium Bosnia and Herzegovina
# count    43.000000     96.000000     96.000000              41.000000
# mean    357.209302    525.250000    494.291667             210.731707
# std    1143.650807   2546.425792   2286.179750             657.803885
# min      96.000000     72.000000     72.000000             108.000000
# 25%     192.000000    274.000000    264.000000             108.000000
# 50%     192.000000    274.000000    264.000000             108.000000
# 75%     192.000000    274.000000    264.000000             108.000000
# max    7680.000000  25212.000000  22660.000000            4320.000000
#
#                                                                              \
#            Bulgaria       Croatia        Cyprus       Czechia       Denmark
# count     95.000000     75.000000     95.000000     95.000000     95.000000
# ...

# %%
eu_diffdiff = pd.read_csv('eu_diffdiff.csv')
eu_diffdiff
# Out:
#              0  Albana  Albanb  Albanc  Alband  Albane  Albanf  Albang  \
# 0   1995-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   1995-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   1995-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   1995-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   1996-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5   1996-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6   1996-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7   1996-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8   1997-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9   1997-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10  1997-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11  1997-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
eu_diffdiff.describe()
# Out:
#           Albana     Albanb     Albanc     Alband     Albane     Albanf  \
# count  35.000000  35.000000  35.000000  35.000000  35.000000  35.000000
# mean    0.317143  -0.097143   0.237143   0.345714  -0.228571  -0.434286
# std    24.550434  10.074064  33.918545   5.672760  34.631026   6.883097
# min   -58.900000 -24.400000 -72.400000  -8.700000 -65.100000 -24.500000
# 25%   -12.650000  -5.950000 -11.700000  -3.850000 -20.500000  -2.750000
# 50%     0.100000   0.200000   1.100000  -0.400000  -0.300000   0.200000
# 75%    14.200000   2.700000  21.150000   3.500000  21.600000   3.700000
# max    49.100000  23.300000  70.700000  12.400000  68.500000  10.100000
#
#           Albang     Albanh     Albani    Albanj      ...            Uniteb  \
# count  35.000000  35.000000  35.000000  35.00000      ...         87.000000
# mean    0.734286   0.191429  -0.048571   0.34000      ...         11.644828
# std    10.886444   7.758615  14.385417   6.10136      ...       1129.479776
# ...

# %%
eu_short = pd.read_csv('eu_short.csv')
eu_short
# Out:
#              0  Albana  Albanb  Albanc  Alband  Albane  Albanf  Albang  \
# 0   1995-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   1995-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   1995-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   1995-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   1996-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5   1996-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6   1996-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7   1996-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8   1997-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9   1997-04-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10  1997-07-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11  1997-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
eu_short.plot(legend = False)

# %%
eu_very_short = pd.read_csv('eu_very_short.csv')
eu_very_short.plot(legend=False)

# %%
gdp_geo = pd.read_csv('gdp_geo.csv')
gdp_geo
#gdp_eu.geo.unique()
#gdp_eu.plot()
# Out:
#      Unnamed: 0   values           values.1            values.2  \
# 0           geo  Austria             Cyprus             Czechia
# 1          time      NaN                NaN                 NaN
# 2    1980-01-01      NaN                NaN                 NaN
# 3    1980-04-01      NaN                NaN                 NaN
# 4    1980-07-01      NaN                NaN                 NaN
# 5    1980-10-01      NaN                NaN                 NaN
# 6    1981-01-01      NaN                NaN                 NaN
# 7    1981-04-01      NaN                NaN                 NaN
# 8    1981-07-01      NaN                NaN                 NaN
# 9    1981-10-01      NaN                NaN                 NaN
# 10   1982-01-01      NaN                NaN                 NaN
# 11   1982-04-01      NaN                NaN                 NaN
# 12   1982-07-01      NaN                NaN                 NaN
# 13   1982-10-01      NaN                NaN                 NaN
# ...
