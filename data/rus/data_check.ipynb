# %%
import pandas as pd
import numpy as np

# %%
vrp_ind = pd.read_csv('rus_vrp_ind.csv', index_col=0, header=[0])

# %%
vrp_ind.columns = vrp_ind.columns.str.upper()

# %%
vrp_ind = vrp_ind.set_index(pd.Index(range(2004, 2017)))

# %%
vrp_ind.to_csv('rus_vrp_ind.csv')

# %%
rus_vrp = pd.read_csv('rus_vrp.csv', index_col=0, header=[0])

# %%
22+9+46+1+1
# Out:
# 79

# %%
list_col = rus_vrp.columns
list_col_2 = [i.replace('Сахал','яяяяя').replace('Саха','Сахя').replace('яяяяя','Сахал').replace('Алтайский','Алкр').replace('Краснодарский','Крад').replace('Красноярский','Края').upper()[:4] for i in list(list_col)]
rus_vrp.columns = pd.Index(list_col_2)

# %%
vrp_ind.columns[::15] == [i+"A" for i in list_col_2]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
rus_vrp.to_csv('rus_vrp_renamed.csv')

# %%
pd.read_csv('rosstat/rus_gdp_q9518.csv', index_col=0, parse_dates=True).plot();

# %%
pd.read_csv('rosstat/rus_gdp_y9518.csv', index_col=0, parse_dates=True).plot();

# %%
pd.read_csv('rosstat/rus_gdp_qspen.csv', index_col=0, parse_dates=True).plot();

# %%
pd.read_csv('rosstat/rus_gdp_qind.csv', index_col=0, parse_dates=True).plot(legend=False);
