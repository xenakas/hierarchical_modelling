# %%
import pandas as pd
import numpy as np

# %%
df_gdp = pd.read_csv('new_gdp_us_state_ind.csv', index_col='date')
df_gdp
# Out:
#              AKACC   AKADM  AKAGR  AKART   AKCON  AKDUR  AKEDC   AKFIN  \
# date
# 2005-01-01  1290.7   750.3  267.6  207.1  2501.0  165.8  164.9  1352.7
# 2005-04-01  1296.3   789.9  317.8  208.5  2511.6  167.0  164.3  1355.9
# 2005-07-01  1293.6   791.2  450.6  213.3  2462.5  162.9  171.1  1430.8
# 2005-10-01  1297.9   753.9  632.0  209.3  2342.2  158.3  180.0  1397.3
# 2006-01-01  1323.2   752.8  482.2  203.6  2324.5  164.4  172.5  1260.2
# 2006-04-01  1346.4   763.0  434.8  212.2  2292.1  162.5  171.1  1204.6
# 2006-07-01  1342.2   770.5  397.4  202.9  2179.8  163.2  171.6  1181.7
# 2006-10-01  1332.1   803.3  419.9  203.8  2191.4  166.8  168.2  1178.5
# 2007-01-01  1346.5   815.6  350.5  215.3  2172.6  174.8  170.7  1162.6
# 2007-04-01  1337.0   852.7  382.0  220.9  2238.1  178.6  172.2  1190.4
# 2007-07-01  1342.9   860.7  392.1  221.4  2200.9  187.1  168.0  1145.8
# 2007-10-01  1341.3   878.8  349.9  223.8  2239.5  189.4  159.8  1100.2
# ...

# %%
descr = df_gdp.describe().transpose()
descr
# Out:
#        count          mean          std      min        25%       50%  \
# AKACC   54.0   1328.368519    45.318466   1256.5   1295.400   1326.55
# AKADM   54.0    962.707407   102.679679    750.3    907.750    973.85
# AKAGR   54.0    429.581481    85.078836    267.6    364.075    431.55
# AKART   54.0    249.901852    30.520253    202.9    221.725    258.30
# AKCON   54.0   2003.240741   277.207387   1515.5   1777.100   2068.45
# AKDUR   54.0    189.444444    19.879132    158.3    173.350    190.80
# AKEDC   54.0    174.796296     6.254024    159.8    171.100    174.75
# AKFIN   54.0   1093.935185   135.209901    809.7   1048.100   1103.05
# AKGOV   54.0   9639.672222   313.649555   9111.8   9354.875   9643.25
# AKHLT   54.0   3132.659259   452.436649   2417.9   2695.300   3238.20
# AKINF   54.0   1217.375926   186.038697    897.2   1082.875   1147.25
# AKMAN   54.0   1596.150000   319.883912    922.7   1437.950   1662.00
# ...

# %%
descr[descr['count'] < 54]
# Out:
#        count         mean         std     min       25%      50%       75%  \
# DEAGR   12.0   536.616667  103.104949   371.3   447.850   542.35   635.575
# DECON   50.0  2046.344000  319.928744  1619.6  1772.975  1995.30  2209.075
# DEMIN    8.0     1.562500    0.879834     0.7     0.700     1.50     2.425
# MEAGR   42.0   928.661905  117.929481   721.8   873.325   907.85   960.800
# MEMIN   42.0    24.645238    7.316577    14.5    17.300    25.25    29.000
# RIAGR   24.0   132.712500   23.849060    92.4   116.450   124.70   151.575
# RICON   48.0  2158.260417  414.145830  1687.7  1816.450  2004.40  2430.750
# RIMIN   24.0    43.766667    9.957941    22.4    43.275    46.25    47.700
# WYAGR   48.0   701.806250  147.417380   358.8   630.550   698.00   785.575
# WYDUR   48.0   399.191667   40.449348   327.4   363.550   407.15   431.150
# WYMAN   48.0  2567.141667  777.070822  1766.8  2136.850  2288.15  2560.200
# ...

# %%
df_gdp.loc[:, df_gdp.isna().any()]
# Out:
#             DEAGR   DECON  DEMIN   MEAGR  MEMIN  RIAGR   RICON  RIMIN  WYAGR  \
# date
# 2005-01-01  633.9     NaN    NaN   819.9   17.6  116.3  2980.7   60.0  638.6
# 2005-04-01  669.2     NaN    NaN   892.9   16.4  125.2  2986.5   59.1  685.8
# 2005-07-01  656.1     NaN    NaN  1065.4   14.9  151.1  2894.2   48.9  669.5
# 2005-10-01  640.6     NaN    NaN  1330.1   15.9  189.1  2819.9   45.4  616.6
# 2006-01-01  532.2  2945.8    2.5  1141.6   14.9  165.4  2820.0   46.4  648.0
# 2006-04-01  584.6  2805.2    2.5  1132.8   15.0  160.0  2857.1   43.3  738.3
# 2006-07-01  552.5  2743.0    2.4  1062.1   16.5  153.0  2840.4   43.2  704.8
# 2006-10-01  503.4  2529.7    2.1  1087.6   16.8  160.3  2762.4   46.8  635.2
# 2007-01-01  454.1  2480.1    0.9   875.6   14.5  114.6  2793.6   43.9  486.0
# 2007-04-01  429.1  2426.6    0.7   911.4   16.4  118.5  2689.7   47.6  455.0
# 2007-07-01  412.4  2446.6    0.7   924.9   19.6  119.4  2636.8   47.2  448.2
# ...

# %%
df_gdp
# Out:
#              AKACC   AKADM  AKAGR  AKART   AKCON  AKDUR  AKEDC   AKFIN  \
# date
# 2005-01-01  1290.7   750.3  267.6  207.1  2501.0  165.8  164.9  1352.7
# 2005-04-01  1296.3   789.9  317.8  208.5  2511.6  167.0  164.3  1355.9
# 2005-07-01  1293.6   791.2  450.6  213.3  2462.5  162.9  171.1  1430.8
# 2005-10-01  1297.9   753.9  632.0  209.3  2342.2  158.3  180.0  1397.3
# 2006-01-01  1323.2   752.8  482.2  203.6  2324.5  164.4  172.5  1260.2
# 2006-04-01  1346.4   763.0  434.8  212.2  2292.1  162.5  171.1  1204.6
# 2006-07-01  1342.2   770.5  397.4  202.9  2179.8  163.2  171.6  1181.7
# 2006-10-01  1332.1   803.3  419.9  203.8  2191.4  166.8  168.2  1178.5
# 2007-01-01  1346.5   815.6  350.5  215.3  2172.6  174.8  170.7  1162.6
# 2007-04-01  1337.0   852.7  382.0  220.9  2238.1  178.6  172.2  1190.4
# 2007-07-01  1342.9   860.7  392.1  221.4  2200.9  187.1  168.0  1145.8
# 2007-10-01  1341.3   878.8  349.9  223.8  2239.5  189.4  159.8  1100.2
# ...

# %%
import matplotlib.pyplot as pp

pp.figure(figsize = (18, 8))
pp.plot(df_gdp);

# %%
tot_gdp = pd.read_csv('new_total_ind.csv', index_col='date')
tot_gdp
# Out:
#                  AK        AL        AR        AZ         CA        CO  \
# date
# 2005-01-01  44760.5  179355.5  103203.5  255921.4  1959066.5  249467.8
# 2005-04-01  45182.9  181373.0  103855.9  261073.7  1976140.0  250972.5
# 2005-07-01  44829.0  181292.6  104669.7  267038.7  2004193.3  252697.5
# 2005-10-01  45434.0  183522.6  106884.1  268210.0  2021163.3  250220.8
# 2006-01-01  46682.9  183884.5  106395.5  274037.7  2069332.5  255571.0
# 2006-04-01  48226.1  185071.6  107870.8  274942.9  2061917.5  254130.1
# 2006-07-01  48812.8  185017.6  107027.0  278323.4  2072917.1  257421.7
# 2006-10-01  50346.4  185211.9  106466.6  281849.0  2084540.9  257374.5
# 2007-01-01  50707.8  184001.5  104012.0  282009.3  2076506.4  258827.4
# 2007-04-01  51595.1  185320.9  104804.5  284354.6  2090690.9  262964.8
# 2007-07-01  51499.7  186728.3  105157.4  287204.7  2107585.8  265471.8
# 2007-10-01  50653.6  187424.6  110647.4  286059.6  2139689.7  271044.1
# ...

# %%
pp.figure(figsize = (30, 20))
pp.plot(tot_gdp)
pp.legend(tot_gdp.columns.unique())

time = pp.gca()
time.set_xticks(pd.date_range(start=min(tot_gdp.index), end=max(tot_gdp.index), freq = '3Y'))
time.set_xticklabels(np.arange(2005,2020,3), rotation=20)
# Out:
# [Text(0,0,'2005'),
#  Text(0,0,'2008'),
#  Text(0,0,'2011'),
#  Text(0,0,'2014'),
#  Text(0,0,'2017')]

# %%
pp.figure(figsize = (30, 20))
pp.plot(tot_gdp)
pp.legend(tot_gdp.columns.unique());

# time = pp.gca()
# time.set_xticks(pd.date_range(start=min(tot_gdp.index), end=max(tot_gdp.index), freq = '3Y'))
# time.set_xticklabels(np.arange(2005,2020,3), rotation=20)

# %%
tot_gdp.index
# Out:
# Index(['2005-01-01', '2005-04-01', '2005-07-01', '2005-10-01', '2006-01-01',
#        '2006-04-01', '2006-07-01', '2006-10-01', '2007-01-01', '2007-04-01',
#        '2007-07-01', '2007-10-01', '2008-01-01', '2008-04-01', '2008-07-01',
#        '2008-10-01', '2009-01-01', '2009-04-01', '2009-07-01', '2009-10-01',
#        '2010-01-01', '2010-04-01', '2010-07-01', '2010-10-01', '2011-01-01',
#        '2011-04-01', '2011-07-01', '2011-10-01', '2012-01-01', '2012-04-01',
#        '2012-07-01', '2012-10-01', '2013-01-01', '2013-04-01', '2013-07-01',
#        '2013-10-01', '2014-01-01', '2014-04-01', '2014-07-01', '2014-10-01',
#        '2015-01-01', '2015-04-01', '2015-07-01', '2015-10-01', '2016-01-01',
#        '2016-04-01', '2016-07-01', '2016-10-01', '2017-01-01', '2017-04-01',
#        '2017-07-01', '2017-10-01', '2018-01-01', '2018-04-01'],
#       dtype='object', name='date')
